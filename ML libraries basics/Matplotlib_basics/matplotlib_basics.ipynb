# %%
import matplotlib.pyplot as plt
# %matplotlib inline
x = [i for i in range(5)]
y = [i for i in range(5)]
plt.plot(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
x = [i for i in range(5)]
y = [i for i in range(5)]
plt.scatter(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
import random
# %matplotlib inline
x = [i for i in range(5)]
y = [i for i in range(5)]
plt.box(1) 
plt.show()
